# %%
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
# !pip install chardet
import chardet
with open ("spam.csv",'rb') as rawdata:
    result = chardet.detect(rawdata.read(5572))
    result

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("spam.csv", encoding='ISO-8859-1')

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# ...

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.v1.value_counts()
# Out:
# ham     4825
# spam     747
# Name: v1, dtype: int64

# %%
df.v1=pd.Categorical(df.v1).codes
df
# Out:
#       v1                                                 v2 Unnamed: 2  \
# 0      0  Go until jurong point, crazy.. Available only ...        NaN
# 1      0                      Ok lar... Joking wif u oni...        NaN
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      0  U dun say so early hor... U c already then say...        NaN
# 4      0  Nah I don't think he goes to usf, he lives aro...        NaN
# ...   ..                                                ...        ...
# 5567   1  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   0              Will Ì_ b going to esplanade fr home?        NaN
# 5569   0  Pity, * was in mood for that. So...any other s...        NaN
# 5570   0  The guy did some bitching but I acted like i'd...        NaN
# 5571   0                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# ...

# %%
df=df.drop(["Unnamed: 2","Unnamed: 3","Unnamed: 4"], axis=1)

# %%
df
# Out:
#       v1                                                 v2
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
# ...   ..                                                ...
# 5567   1  This is the 2nd time we have tried 2 contact u...
# 5568   0              Will Ì_ b going to esplanade fr home?
# 5569   0  Pity, * was in mood for that. So...any other s...
# 5570   0  The guy did some bitching but I acted like i'd...
# 5571   0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.rename(columns={'v1':  'type', 'v2': 'SMS'},inplace=True)

# %%
df
# Out:
#       type                                                SMS
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567     1  This is the 2nd time we have tried 2 contact u...
# 5568     0              Will Ì_ b going to esplanade fr home?
# 5569     0  Pity, * was in mood for that. So...any other s...
# 5570     0  The guy did some bitching but I acted like i'd...
# 5571     0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.type,df.SMS
# Out:
# (0       0
#  1       0
#  2       1
#  3       0
#  4       0
#         ..
#  5567    1
#  5568    0
#  5569    0
#  5570    0
#  5571    0
#  Name: type, Length: 5572, dtype: int8,
#  0       Go until jurong point, crazy.. Available only ...
#  1                           Ok lar... Joking wif u oni...
#  2       Free entry in 2 a wkly comp to win FA Cup fina...
#  3       U dun say so early hor... U c already then say...
#  4       Nah I don't think he goes to usf, he lives aro...
#                                ...
#  5567    This is the 2nd time we have tried 2 contact u...
#  5568                Will Ì_ b going to esplanade fr home?
#  5569    Pity, * was in mood for that. So...any other s...
#  5570    The guy did some bitching but I acted like i'd...
#  5571                           Rofl. Its true to its name
#  Name: SMS, Length: 5572, dtype: object)

# %%
numbers=df.type.value_counts()
sns.barplot(x=numbers.index,y=numbers)
plt.show()

# %%
count_class_0,count_class_1=df.type.value_counts()
data_class_0=df[df["type"]==0]
data_class_1=df[df["type"]==1]

# %%
count_class_0,count_class_1

data_class_under=data_class_0.sample(count_class_1)
data_under=pd.concat([data_class_under,data_class_1],axis=0)

df
# Out:
#       type                                                SMS
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567     1  This is the 2nd time we have tried 2 contact u...
# 5568     0              Will Ì_ b going to esplanade fr home?
# 5569     0  Pity, * was in mood for that. So...any other s...
# 5570     0  The guy did some bitching but I acted like i'd...
# 5571     0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
def pre(desc):
  d=nlp(desc)
  filtered_tokens=[]
  for token in d:
    if token.is_stop or token.is_punct:
      continue
    filtered_tokens.append(token.lemma_)
    return " ".join(filtered_tokens)

# %%
data_under["New_SMS"]=data_under.SMS.apply(pre)

# %%
df
# Out:
#       type                                                SMS
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567     1  This is the 2nd time we have tried 2 contact u...
# 5568     0              Will Ì_ b going to esplanade fr home?
# 5569     0  Pity, * was in mood for that. So...any other s...
# 5570     0  The guy did some bitching but I acted like i'd...
# 5571     0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
data_under=data_under.drop("SMS",axis=1)
data_under
# Out:
#       type     New_SMS
# 4502     0   stupid.it
# 4166     0        work
# 791      0           e
# 1300     0  cocksucker
# 5344     0         guy
# ...    ...         ...
# 5537     1        want
# 5540     1       ASKED
# 5547     1    contract
# 5566     1    reminder
# 5567     1         2nd
#
# [1494 rows x 2 columns]

# %%
from  sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,y_test = train_test_split(data_under.New_SMS,data_under.type,test_size=0.2,random_state=1,stratify=data_under.type    )

# %%
print("\nMissing values in X_train:")
print(X_train.isnull().sum())
print("\nMissing values in Y_train:")
print(Y_train.isnull().sum())
# Out:
# Missing values in X_train:
# 3
#
# Missing values in Y_train:
# 0

# %%
X_train = X_train.fillna('')  # Replace NaN values with empty strings
Y_train = Y_train.fillna(0)   # Replace NaN values with 0 (or appropriate imputation)

# %%
print("\nMissing values in X_train:")
print(X_train.isnull().sum())
print("\nMissing values in Y_train:")
print(Y_train.isnull().sum())
# Out:
# Missing values in X_train:
# 0
#
# Missing values in Y_train:
# 0

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
Model=Pipeline(
[
    ('vectorizer_tfidf',TfidfVectorizer()),
    ('Multi NB',MultinomialNB())
])
Model.fit(X_train,Y_train)
y_pred=Model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81       149
#            1       0.87      0.69      0.77       150
#
#     accuracy                           0.79       299
#    macro avg       0.80      0.79      0.79       299
# weighted avg       0.81      0.79      0.79       299
